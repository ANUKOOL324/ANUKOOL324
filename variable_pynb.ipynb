# %% [markdown]
# <a href="https://colab.research.google.com/github/ANUKOOL324/ANUKOOL324/blob/main/variable_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Calculate the following
# Total Salary = (Base Salary) * (1 + Bonus Rate)

# %%
base_salary = 10000
bonus_rate = 0.10

# %%
total_salary = (base_salary)*(1+ bonus_rate)

# %%
total_salary
# Out:
# 11000.0

# %%
print("hher")
# Out:
# hher

# %%
my_print_function = print #creating variable for a function

# %%
my_print_function('jfndjf')
# Out:
# jfndjf

# %%
def greet() :
  return "eherrje"
greet()
# Out:
# 'eherrje'

# %%
car = "dfjndf"
job_location='sjds'
print(f"car: {car}\nlocation: {job_location}")
# Out:
# car: dfjndf
# location: sjds
